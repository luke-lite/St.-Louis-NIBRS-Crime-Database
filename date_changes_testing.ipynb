# %%
import sqlite3
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
with sqlite3.connect('data/database.db') as conn:
    # df = pd.read_sql_query("SELECT LastUpdated FROM meta_data", conn)
    updated_df = pd.read_sql_query("""
        SELECT IncidentNum,IncidentDate,TimeOccurred,SLMPDOffense,
               NIBRSCode,NIBRSCat,NIBRSOffenseType,UCR_SRS,CrimeGrade,
               PrimaryLocation,SecondaryLocation,District,Neighborhood,
               NeighborhoodNum,Latitude,Longitude,Supplemented,
               SupplementDate,VictimNum,FirearmUsed,IncidentNature
        FROM crime_data
        """, conn)

# %%
df
# Out:
# Empty DataFrame
# Columns: [LastUpdated]
# Index: []

# %%
updated_df
# Out:
#         IncidentNum IncidentDate TimeOccurred  \
# 0          21000002   2021-01-01      02:00.0
# 1          21000003   2021-01-01      09:00.0
# 2          21000003   2021-01-01      09:00.0
# 3          21000007   2021-01-01      10:00.0
# 4          21000008   2021-01-01      20:00.0
# ...             ...          ...          ...
# 185107     24013246   2024-03-31     14:00:00
# 185108     24013297   2024-03-10     16:20:00
# 185109     24013320   2024-03-22     12:50:00
# 185110     24013330   2024-03-08     11:00:00
# 185111     24013347   2024-03-30     09:30:00
#
#                                              SLMPDOffense NIBRSCode  \
# 0                          MISCELLANEOUS WEAPON VIOLATION       520
# 1                          MISCELLANEOUS WEAPON VIOLATION       520
# 2                                         PROPERTY DAMAGE       290
# 3                            PROPERTY DAMAGE - 2ND DEGREE       290
# 4                          MISCELLANEOUS WEAPON VIOLATION       520
# ...                                                   ...       ...
# 185107  PROPERTY DAMAGE - 1ST DEGREE - DAMAGE TO MOTOR...       290
# 185108              ENGAGING IN OR MAINTAINING A NUISANCE       90Z
# 185109       STEALING - MOTOR VEHICLE/WATERCRAFT/AIRCRAFT       240
# 185110       STEALING - MOTOR VEHICLE/WATERCRAFT/AIRCRAFT       240
# 185111  ASSAULT- 4TH DEGREE - PURSUANT TO SUBDIVISION ...       13B
#
#            NIBRSCat                          NIBRSOffenseType  UCR_SRS  \
# 0              None                                      None      NaN
# 1              None                                      None      NaN
# 2              None                                      None      NaN
# 3              None                                      None      NaN
# 4              None                                      None      NaN
# ...             ...                                       ...      ...
# 185107     Property  Destruction/Damage/Vandalism of Property      NaN
# 185108  Unspecified                        All Other Offenses      NaN
# 185109     Property                       Motor Vehicle Theft      7.0
# 185110     Property                       Motor Vehicle Theft      7.0
# 185111       Person                            Simple Assault      NaN
#
#        CrimeGrade           PrimaryLocation SecondaryLocation District  \
# 0            None          1700 CHESTNUT ST              None      4.0
# 1            None          4961 LACLEDE AVE               210      5.0
# 2            None          4961 LACLEDE AVE               210      5.0
# 3            None           6963 PERNOD AVE              None      2.0
# 4            None         3500 KINGSLAND CT              None      1.0
# ...           ...                       ...               ...      ...
# 185107          F  1500 N KINGSHIGHWAY BLVD              None        5
# 185108       None            1911 LOCUST ST              None        4
# 185109          F           8880 N BROADWAY              None        6
# 185110          F              8505 PARK LN              None        6
# 185111          M  2727 N KINGSHIGHWAY BLVD              None        5
#
#          Neighborhood NeighborhoodNum   Latitude  Longitude Supplemented  \
# 0                None              36  38.629573 -90.204995         None
# 1                None              38  38.641221 -90.264226         None
# 2                None              38  38.641221 -90.264226         None
# 3                None               9  38.598725 -90.310722         None
# 4                None              16  38.579494 -90.243210         None
# ...               ...             ...        ...        ...          ...
# 185107  Kingsway East              55  38.663049 -90.261440           No
# 185108  Downtown West              36  38.633143 -90.207530           No
# 185109          Baden              74  38.726063 -90.227567           No
# 185110   North Pointe              73  38.713885 -90.247990           No
# 185111  Kingsway West              52  38.669778 -90.257138           No
#
#        SupplementDate  VictimNum FirearmUsed                   IncidentNature
# 0                None        NaN        None                             None
# 1                None        NaN        None                             None
# 2                None        NaN        None                             None
# 3                None        NaN        None                             None
# 4                None        NaN        None                             None
# ...               ...        ...         ...                              ...
# 185107           None        NaN          No               Larceny - Criminal
# 185108           None        NaN          No  Offenses - All Other - Criminal
# 185109           None        NaN          No   Motor Vehicle Theft - Criminal
# 185110           None        NaN          No   Motor Vehicle Theft - Criminal
# 185111           None   389857.0          No        Simple Assault - Criminal
#
# [185112 rows x 21 columns]

# %%
df = pd.read_csv('uploads/Crime2021-2023.csv')
df
