# %%
import sqlite3
import geopandas as gpd
import numpy as np
import shapely.geometry
from shapely.geometry import Point
import shapely.ops
import shapely
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# geostl nghbd codes:
    # gravois park = 19
    # benton park west = 30
    # dutchtown = 16
    # mount pleasant = 17

# %%
# conn=sqlite3.connect('test_db.db')
conn = sqlite3.connect('database.db')

# %%
df = pd.read_sql_query("""SELECT IncidentNum,IncidentDate,TimeOccurred,SLMPDOffense,
                                 NIBRSCode,NIBRSCat,NIBRSOffenseType,UCR_SRS,CrimeGrade,
                                 PrimaryLocation,SecondaryLocation,District,Neighborhood,
                                 NeighborhoodNum,Latitude,Longitude,Supplemented,
                                 SupplementDate,VictimNum,FirearmUsed,IncidentNature
                          FROM crime_data""", conn)
df = df.sort_values(['IncidentDate', 'IncidentNum'])

# %%
df
# Out:
#         IncidentNum IncidentDate TimeOccurred  \
# 0          21000002   2021-01-01      02:00.0
# 1          21000003   2021-01-01      09:00.0
# 2          21000003   2021-01-01      09:00.0
# 3          21000007   2021-01-01      10:00.0
# 4          21000008   2021-01-01      20:00.0
# ...             ...          ...          ...
# 177534     24004797   2024-01-31     22:00:00
# 175592     24004856   2024-01-31     17:30:00
# 177558     24005157   2024-01-31     10:00:00
# 177559     24005186   2024-01-31     23:30:00
# 177587     24007205   2024-01-31     00:01:00
#
#                                              SLMPDOffense NIBRSCode  NIBRSCat  \
# 0                          MISCELLANEOUS WEAPON VIOLATION       520      None
# 1                          MISCELLANEOUS WEAPON VIOLATION       520      None
# 2                                         PROPERTY DAMAGE       290      None
# 3                            PROPERTY DAMAGE - 2ND DEGREE       290      None
# 4                          MISCELLANEOUS WEAPON VIOLATION       520      None
# ...                                                   ...       ...       ...
# 177534  ASSAULT- 4TH DEGREE - PURSUANT TO SUBDIVISION (3)       13B    Person
# 175592                            STEALING - $750 OR MORE       23G  Property
# 177558       STEALING - MOTOR VEHICLE/WATERCRAFT/AIRCRAFT       240  Property
# 177559       STEALING - MOTOR VEHICLE/WATERCRAFT/AIRCRAFT       240  Property
# 177587      DESTRUCTION OF PRIVATE PROPERTY (CITY CHARGE)       290  Property
#
#                                   NIBRSOffenseType  UCR_SRS CrimeGrade  \
# 0                                             None      NaN       None
# 1                                             None      NaN       None
# 2                                             None      NaN       None
# 3                                             None      NaN       None
# 4                                             None      NaN       None
# ...                                            ...      ...        ...
# 177534                              Simple Assault      NaN          M
# 175592  Theft From Motor Vehicle Parts/Accessories      6.0          F
# 177558                         Motor Vehicle Theft      7.0          F
# 177559                         Motor Vehicle Theft      7.0          F
# 177587    Destruction/Damage/Vandalism of Property      NaN       None
#
#               PrimaryLocation SecondaryLocation District  \
# 0            1700 CHESTNUT ST              None      4.0
# 1            4961 LACLEDE AVE               210      5.0
# 2            4961 LACLEDE AVE               210      5.0
# 3             6963 PERNOD AVE              None      2.0
# 4           3500 KINGSLAND CT              None      1.0
# ...                       ...               ...      ...
# 177534  6055 W FLORISSANT AVE              None      6.0
# 175592           300 N 4TH ST              None      4.0
# 177558       1250 BLUMEYER ST              None      4.0
# 177559         I 70 WESTBOUND        MADISON ST      4.0
# 177587        7208 N BROADWAY              None      6.0
#
#                      Neighborhood NeighborhoodNum   Latitude  Longitude  \
# 0                            None              36  38.629573 -90.204995
# 1                            None              38  38.641221 -90.264226
# 2                            None              38  38.641221 -90.264226
# 3                            None               9  38.598725 -90.310722
# 4                            None              16  38.579494 -90.243210
# ...                           ...             ...        ...        ...
# 177534               North Pointe              73  38.710429 -90.252241
# 175592                   Downtown              35  38.628159 -90.186982
# 177558  Covenant Blu Grand Center              77  38.643889 -90.225851
# 177559         Old North St Louis              63  38.652490 -90.193730
# 177587           North Riverfront              79  38.631053 -90.187720
#
#        Supplemented               SupplementDate  VictimNum FirearmUsed  \
# 0              None                         None        NaN        None
# 1              None                         None        NaN        None
# 2              None                         None        NaN        None
# 3              None                         None        NaN        None
# 4              None                         None        NaN        None
# ...             ...                          ...        ...         ...
# 177534           No                         None   371360.0          No
# 175592          Yes  2024-02-06 14:33:46.0630000        NaN          No
# 177558           No                         None        NaN          No
# 177559           No                         None        NaN          No
# 177587           No                         None        NaN          No
#
#                             IncidentNature
# 0                                     None
# 1                                     None
# 2                                     None
# 3                                     None
# 4                                     None
# ...                                    ...
# 177534           Simple Assault - Criminal
# 175592                  Larceny - Criminal
# 177558      Motor Vehicle Theft - Criminal
# 177559      Motor Vehicle Theft - Criminal
# 177587  Destruction of Property - Criminal
#
# [177591 rows x 21 columns]

# %%
conn.close()

# %%
conn=sqlite3.connect('database.db')

# %%
df = pd.read_sql_query("""SELECT IncidentNum,IncidentDate,TimeOccurred,SLMPDOffense,
                                 NIBRSCode,NIBRSCat,NIBRSOffenseType,UCR_SRS,CrimeGrade,
                                 PrimaryLocation,SecondaryLocation,District,Neighborhood,
                                 NeighborhoodNum,Latitude,Longitude,Supplemented,
                                 SupplementDate,VictimNum,FirearmUsed,IncidentNature
                          FROM crime_data""", conn)
df = df.sort_values(['IncidentDate', 'IncidentNum'])
df

# %%
nibrs_df =

# %%
nibrs_geo = [Point(xy) for xy in zip(nibrs_df['longitude'], nibrs_df['latitude'])]
# nibrs_df = gpd.GeoDataFrame(nibrs_df, geometry=nibrs_geo)
# nibrs_df['date_inc'] = pd.to_datetime(nibrs_df['date_inc'])

# nghbrhd_list = ['16', '17', '19', '30']
# mask = nibrs_df['neighborhood'].isin(nghbrhd_list)
# nbhd_nibrs_df = nibrs_df[mask]
# nbhd_nibrs_df

# %%
pd.read_csv('uploads/Crime2021-2023.csv')

# %%
import sqlite3
# import pandas as pd
from refactor import DataTransformer

# %%
# Connect to SQLite database
conn = sqlite3.connect('database.db')

with conn:
    DT = DataTransformer(filename='Crime_01_2024',
                         upload_path='uploads/Crime_01_2024.csv',
                         conn=conn)
    
    DT.clean_data()
    DT.split_data()
    DT.integrity_check()
    DT.update_db_from_supp()
    DT.update_db_from_unfound()
    DT.update_db_from_new()
    DT.commit_to_db()
    updated_df = DT.get_updated_df()
    supp_df, unfound_df, new_df = DT.get_split_dfs()

# %%
updated_df

# %%
updated_df
