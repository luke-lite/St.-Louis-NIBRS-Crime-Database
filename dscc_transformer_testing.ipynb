# %%
import sqlite3
import geopandas as gpd
import numpy as np
import shapely.geometry
from shapely.geometry import Point
import shapely.ops
import shapely
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# geostl nghbd codes:
    # gravois park = 19
    # benton park west = 30
    # dutchtown = 16
    # mount pleasant = 17

# %%
# conn=sqlite3.connect('test_db.db')
conn = sqlite3.connect('data/database.db')

# %%
df = pd.read_sql_query("""SELECT IncidentNum,IncidentDate,TimeOccurred,SLMPDOffense,
                                 NIBRSCode,NIBRSCat,NIBRSOffenseType,UCR_SRS,CrimeGrade,
                                 PrimaryLocation,SecondaryLocation,District,Neighborhood,
                                 NeighborhoodNum,Latitude,Longitude,Supplemented,
                                 SupplementDate,VictimNum,FirearmUsed,IncidentNature
                          FROM crime_data""", conn)
df = df.sort_values(['IncidentDate', 'IncidentNum'])

# %%
df
# Out:
#         IncidentNum IncidentDate TimeOccurred  \
# 0          21000002   2021-01-01      02:00.0
# 1          21000003   2021-01-01      09:00.0
# 2          21000003   2021-01-01      09:00.0
# 3          21000007   2021-01-01      10:00.0
# 4          21000008   2021-01-01      20:00.0
# ...             ...          ...          ...
# 173359     24000551   2023-12-31      00:00.0
# 173360     24000557   2023-12-31      00:00.0
# 173361     24000591   2023-12-31      00:00.0
# 173362     24000629   2023-12-31      00:00.0
# 173363     24000707   2023-12-31      25:00.0
#
#                                              SLMPDOffense NIBRSCode NIBRSCat  \
# 0                          MISCELLANEOUS WEAPON VIOLATION       520     None
# 1                          MISCELLANEOUS WEAPON VIOLATION       520     None
# 2                                         PROPERTY DAMAGE       290     None
# 3                            PROPERTY DAMAGE - 2ND DEGREE       290     None
# 4                          MISCELLANEOUS WEAPON VIOLATION       520     None
# ...                                                   ...       ...      ...
# 173359      DESTRUCTION OF PRIVATE PROPERTY (CITY CHARGE)       290     None
# 173360      DESTRUCTION OF PRIVATE PROPERTY (CITY CHARGE)       290     None
# 173361                    DISCHARGING FIREARM WITHIN CITY       520     None
# 173362  STEALING UNDER $150 (PETTY LARCENY-MOTOR VEH P...       23G     None
# 173363                         PROPERTY DAMAGE 1ST DEGREE       290     None
#
#        NIBRSOffenseType UCR_SRS CrimeGrade    PrimaryLocation  \
# 0                  None    None       None   1700 CHESTNUT ST
# 1                  None    None       None   4961 LACLEDE AVE
# 2                  None    None       None   4961 LACLEDE AVE
# 3                  None    None       None    6963 PERNOD AVE
# 4                  None    None       None  3500 KINGSLAND CT
# ...                 ...     ...        ...                ...
# 173359             None    None       None   3920 DUNNICA AVE
# 173360             None    None       None    2007 E FAIR AVE
# 173361             None    None       None     5516 GRACE AVE
# 173362             None    None       None      1500 OLIVE ST
# 173363             None    None       None    1331 SHAWMUT PL
#
#        SecondaryLocation District Neighborhood NeighborhoodNum   Latitude  \
# 0                   None      4.0         None              36  38.629573
# 1                    210      5.0         None              38  38.641221
# 2                    210      5.0         None              38  38.641221
# 3                   None      2.0         None               9  38.598725
# 4                   None      1.0         None              16  38.579494
# ...                  ...      ...          ...             ...        ...
# 173359              None      1.0         None              16  38.587915
# 173360              None      6.0         None              68  38.677708
# 173361              None      1.0         None               3  38.569796
# 173362              None      4.0         None              36  38.630687
# 173363              None      5.0         None              78  38.667339
#
#         Longitude Supplemented SupplementDate VictimNum FirearmUsed  \
# 0      -90.204995         None           None      None        None
# 1      -90.264226         None           None      None        None
# 2      -90.264226         None           None      None        None
# 3      -90.310722         None           None      None        None
# 4      -90.243210         None           None      None        None
# ...           ...          ...            ...       ...         ...
# 173359 -90.252870         None           None      None        None
# 173360 -90.217160         None           None      None        None
# 173361 -90.254490         None           None      None        None
# 173362 -90.201630         None           None      None        None
# 173363 -90.281849         None           None      None        None
#
#        IncidentNature
# 0                None
# 1                None
# 2                None
# 3                None
# 4                None
# ...               ...
# 173359           None
# 173360           None
# 173361           None
# 173362           None
# 173363           None
#
# [173364 rows x 21 columns]

# %%
ids = df['IncidentNum'].value_counts()
ids[ids>1]
# df[df['IncidentNum']==23051429]

# %%
df[df['IncidentNum']==23051429]

# %%
df

# %%
conn.close()

# %%
conn=sqlite3.connect('test_db.db')

# %%
df = pd.read_sql_query("""SELECT IncidentNum,IncidentDate,TimeOccurred,SLMPDOffense,
                                 NIBRSCode,NIBRSCat,NIBRSOffenseType,UCR_SRS,CrimeGrade,
                                 PrimaryLocation,SecondaryLocation,District,Neighborhood,
                                 NeighborhoodNum,Latitude,Longitude,Supplemented,
                                 SupplementDate,VictimNum,FirearmUsed,IncidentNature
                          FROM crime_data""", conn)
df = df.sort_values(['IncidentDate', 'IncidentNum'])
df

# %%
df[df['IncidentNum']==23051429]

# %%
nibrs_df =

# %%
nibrs_geo = [Point(xy) for xy in zip(nibrs_df['longitude'], nibrs_df['latitude'])]
# nibrs_df = gpd.GeoDataFrame(nibrs_df, geometry=nibrs_geo)
# nibrs_df['date_inc'] = pd.to_datetime(nibrs_df['date_inc'])

# nghbrhd_list = ['16', '17', '19', '30']
# mask = nibrs_df['neighborhood'].isin(nghbrhd_list)
# nbhd_nibrs_df = nibrs_df[mask]
# nbhd_nibrs_df

# %%
pd.read_csv('uploads/Crime2021-2023.csv')

# %%
import sqlite3
# import pandas as pd
from refactor import DataTransformer

# %%
# Connect to SQLite database
conn = sqlite3.connect('database.db')

with conn:
    DT = DataTransformer(filename='Crime_01_2024',
                         upload_path='uploads/Crime_01_2024.csv',
                         conn=conn)
    
    DT.clean_data()
    DT.split_data()
    DT.integrity_check()
    DT.update_db_from_supp()
    DT.update_db_from_unfound()
    DT.update_db_from_new()
    DT.commit_to_db()
    updated_df = DT.get_updated_df()
    supp_df, unfound_df, new_df = DT.get_split_dfs()

# %%
updated_df

# %%
updated_df
