# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
old_nibrs = pd.read_csv('uploads/Crime2021-2023.csv')
old_nibrs
# Out:
#         IncidentNum IncidentDate TimeOccurred  \
# 0          21000002   2021-01-01      02:00.0
# 1          21000003   2021-01-01      09:00.0
# 2          21000003   2021-01-01      09:00.0
# 3          21000007   2021-01-01      10:00.0
# 4          21000008   2021-01-01      20:00.0
# ...             ...          ...          ...
# 173359     24000551   2023-12-31      00:00.0
# 173360     24000557   2023-12-31      00:00.0
# 173361     24000591   2023-12-31      00:00.0
# 173362     24000629   2023-12-31      00:00.0
# 173363     24000707   2023-12-31      25:00.0
#
#                                              SLMPDOffense NIBRSCode  NIBRSCat  \
# 0                          MISCELLANEOUS WEAPON VIOLATION       520       NaN
# 1                          MISCELLANEOUS WEAPON VIOLATION       520       NaN
# 2                                         PROPERTY DAMAGE       290       NaN
# 3                            PROPERTY DAMAGE - 2ND DEGREE       290       NaN
# 4                          MISCELLANEOUS WEAPON VIOLATION       520       NaN
# ...                                                   ...       ...       ...
# 173359      DESTRUCTION OF PRIVATE PROPERTY (CITY CHARGE)       290       NaN
# 173360      DESTRUCTION OF PRIVATE PROPERTY (CITY CHARGE)       290       NaN
# 173361                    DISCHARGING FIREARM WITHIN CITY       520       NaN
# 173362  STEALING UNDER $150 (PETTY LARCENY-MOTOR VEH P...       23G       NaN
# 173363                         PROPERTY DAMAGE 1ST DEGREE       290       NaN
#
#         NIBRSOffenseType  UCR_SRS  CrimeGrade    PrimaryLocation  \
# 0                    NaN      NaN         NaN   1700 CHESTNUT ST
# 1                    NaN      NaN         NaN   4961 LACLEDE AVE
# 2                    NaN      NaN         NaN   4961 LACLEDE AVE
# 3                    NaN      NaN         NaN    6963 PERNOD AVE
# 4                    NaN      NaN         NaN  3500 KINGSLAND CT
# ...                  ...      ...         ...                ...
# 173359               NaN      NaN         NaN   3920 DUNNICA AVE
# 173360               NaN      NaN         NaN    2007 E FAIR AVE
# 173361               NaN      NaN         NaN     5516 GRACE AVE
# 173362               NaN      NaN         NaN      1500 OLIVE ST
# 173363               NaN      NaN         NaN    1331 SHAWMUT PL
#
#        SecondaryLocation  District Neighborhood  NeighborhoodNum   Latitude  \
# 0                    NaN       4.0           36              NaN  38.629573
# 1                    210       5.0           38              NaN  38.641221
# 2                    210       5.0           38              NaN  38.641221
# 3                    NaN       2.0            9              NaN  38.598725
# 4                    NaN       1.0           16              NaN  38.579494
# ...                  ...       ...          ...              ...        ...
# 173359               NaN       1.0           16              NaN  38.587915
# 173360               NaN       6.0           68              NaN  38.677708
# 173361               NaN       1.0            3              NaN  38.569796
# 173362               NaN       4.0           36              NaN  38.630687
# 173363               NaN       5.0           78              NaN  38.667339
#
#         Longitude  Supplemented  SupplementDate  VictimNum  FirearmUsed  \
# 0      -90.204995           NaN             NaN        NaN          NaN
# 1      -90.264226           NaN             NaN        NaN          NaN
# 2      -90.264226           NaN             NaN        NaN          NaN
# 3      -90.310722           NaN             NaN        NaN          NaN
# 4      -90.243210           NaN             NaN        NaN          NaN
# ...           ...           ...             ...        ...          ...
# 173359 -90.252870           NaN             NaN        NaN          NaN
# 173360 -90.217160           NaN             NaN        NaN          NaN
# 173361 -90.254490           NaN             NaN        NaN          NaN
# 173362 -90.201630           NaN             NaN        NaN          NaN
# 173363 -90.281849           NaN             NaN        NaN          NaN
#
#         IncidentNature
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 173359             NaN
# 173360             NaN
# 173361             NaN
# 173362             NaN
# 173363             NaN
#
# [173364 rows x 21 columns]

# %%
old_nibrs['NeighborhoodNum'] = old_nibrs['Neighborhood']
old_nibrs['Neighborhood'] = np.nan
old_nibrs
# Out:
#         IncidentNum IncidentDate TimeOccurred  \
# 0          21000002   2021-01-01      02:00.0
# 1          21000003   2021-01-01      09:00.0
# 2          21000003   2021-01-01      09:00.0
# 3          21000007   2021-01-01      10:00.0
# 4          21000008   2021-01-01      20:00.0
# ...             ...          ...          ...
# 173359     24000551   2023-12-31      00:00.0
# 173360     24000557   2023-12-31      00:00.0
# 173361     24000591   2023-12-31      00:00.0
# 173362     24000629   2023-12-31      00:00.0
# 173363     24000707   2023-12-31      25:00.0
#
#                                              SLMPDOffense NIBRSCode  NIBRSCat  \
# 0                          MISCELLANEOUS WEAPON VIOLATION       520       NaN
# 1                          MISCELLANEOUS WEAPON VIOLATION       520       NaN
# 2                                         PROPERTY DAMAGE       290       NaN
# 3                            PROPERTY DAMAGE - 2ND DEGREE       290       NaN
# 4                          MISCELLANEOUS WEAPON VIOLATION       520       NaN
# ...                                                   ...       ...       ...
# 173359      DESTRUCTION OF PRIVATE PROPERTY (CITY CHARGE)       290       NaN
# 173360      DESTRUCTION OF PRIVATE PROPERTY (CITY CHARGE)       290       NaN
# 173361                    DISCHARGING FIREARM WITHIN CITY       520       NaN
# 173362  STEALING UNDER $150 (PETTY LARCENY-MOTOR VEH P...       23G       NaN
# 173363                         PROPERTY DAMAGE 1ST DEGREE       290       NaN
#
#         NIBRSOffenseType  UCR_SRS  CrimeGrade    PrimaryLocation  \
# 0                    NaN      NaN         NaN   1700 CHESTNUT ST
# 1                    NaN      NaN         NaN   4961 LACLEDE AVE
# 2                    NaN      NaN         NaN   4961 LACLEDE AVE
# 3                    NaN      NaN         NaN    6963 PERNOD AVE
# 4                    NaN      NaN         NaN  3500 KINGSLAND CT
# ...                  ...      ...         ...                ...
# 173359               NaN      NaN         NaN   3920 DUNNICA AVE
# 173360               NaN      NaN         NaN    2007 E FAIR AVE
# 173361               NaN      NaN         NaN     5516 GRACE AVE
# 173362               NaN      NaN         NaN      1500 OLIVE ST
# 173363               NaN      NaN         NaN    1331 SHAWMUT PL
#
#        SecondaryLocation  District  Neighborhood NeighborhoodNum   Latitude  \
# 0                    NaN       4.0           NaN              36  38.629573
# 1                    210       5.0           NaN              38  38.641221
# 2                    210       5.0           NaN              38  38.641221
# 3                    NaN       2.0           NaN               9  38.598725
# 4                    NaN       1.0           NaN              16  38.579494
# ...                  ...       ...           ...             ...        ...
# 173359               NaN       1.0           NaN              16  38.587915
# 173360               NaN       6.0           NaN              68  38.677708
# 173361               NaN       1.0           NaN               3  38.569796
# 173362               NaN       4.0           NaN              36  38.630687
# 173363               NaN       5.0           NaN              78  38.667339
#
#         Longitude  Supplemented  SupplementDate  VictimNum  FirearmUsed  \
# 0      -90.204995           NaN             NaN        NaN          NaN
# 1      -90.264226           NaN             NaN        NaN          NaN
# 2      -90.264226           NaN             NaN        NaN          NaN
# 3      -90.310722           NaN             NaN        NaN          NaN
# 4      -90.243210           NaN             NaN        NaN          NaN
# ...           ...           ...             ...        ...          ...
# 173359 -90.252870           NaN             NaN        NaN          NaN
# 173360 -90.217160           NaN             NaN        NaN          NaN
# 173361 -90.254490           NaN             NaN        NaN          NaN
# 173362 -90.201630           NaN             NaN        NaN          NaN
# 173363 -90.281849           NaN             NaN        NaN          NaN
#
#         IncidentNature
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 173359             NaN
# 173360             NaN
# 173361             NaN
# 173362             NaN
# 173363             NaN
#
# [173364 rows x 21 columns]

# %%
old_nibrs.to_csv('uploads/Crime2021-2023.csv', index=False)

# %%
old_nibrs = pd.read_csv('uploads/Crime2021-2023.csv')

# %%
old_nibrs
# Out:
#         IncidentNum IncidentDate TimeOccurred  \
# 0          21000002   2021-01-01      02:00.0
# 1          21000003   2021-01-01      09:00.0
# 2          21000003   2021-01-01      09:00.0
# 3          21000007   2021-01-01      10:00.0
# 4          21000008   2021-01-01      20:00.0
# ...             ...          ...          ...
# 173359     24000551   2023-12-31      00:00.0
# 173360     24000557   2023-12-31      00:00.0
# 173361     24000591   2023-12-31      00:00.0
# 173362     24000629   2023-12-31      00:00.0
# 173363     24000707   2023-12-31      25:00.0
#
#                                              SLMPDOffense NIBRSCode  NIBRSCat  \
# 0                          MISCELLANEOUS WEAPON VIOLATION       520       NaN
# 1                          MISCELLANEOUS WEAPON VIOLATION       520       NaN
# 2                                         PROPERTY DAMAGE       290       NaN
# 3                            PROPERTY DAMAGE - 2ND DEGREE       290       NaN
# 4                          MISCELLANEOUS WEAPON VIOLATION       520       NaN
# ...                                                   ...       ...       ...
# 173359      DESTRUCTION OF PRIVATE PROPERTY (CITY CHARGE)       290       NaN
# 173360      DESTRUCTION OF PRIVATE PROPERTY (CITY CHARGE)       290       NaN
# 173361                    DISCHARGING FIREARM WITHIN CITY       520       NaN
# 173362  STEALING UNDER $150 (PETTY LARCENY-MOTOR VEH P...       23G       NaN
# 173363                         PROPERTY DAMAGE 1ST DEGREE       290       NaN
#
#         NIBRSOffenseType  UCR_SRS  CrimeGrade    PrimaryLocation  \
# 0                    NaN      NaN         NaN   1700 CHESTNUT ST
# 1                    NaN      NaN         NaN   4961 LACLEDE AVE
# 2                    NaN      NaN         NaN   4961 LACLEDE AVE
# 3                    NaN      NaN         NaN    6963 PERNOD AVE
# 4                    NaN      NaN         NaN  3500 KINGSLAND CT
# ...                  ...      ...         ...                ...
# 173359               NaN      NaN         NaN   3920 DUNNICA AVE
# 173360               NaN      NaN         NaN    2007 E FAIR AVE
# 173361               NaN      NaN         NaN     5516 GRACE AVE
# 173362               NaN      NaN         NaN      1500 OLIVE ST
# 173363               NaN      NaN         NaN    1331 SHAWMUT PL
#
#        SecondaryLocation  District  Neighborhood NeighborhoodNum   Latitude  \
# 0                    NaN       4.0           NaN              36  38.629573
# 1                    210       5.0           NaN              38  38.641221
# 2                    210       5.0           NaN              38  38.641221
# 3                    NaN       2.0           NaN               9  38.598725
# 4                    NaN       1.0           NaN              16  38.579494
# ...                  ...       ...           ...             ...        ...
# 173359               NaN       1.0           NaN              16  38.587915
# 173360               NaN       6.0           NaN              68  38.677708
# 173361               NaN       1.0           NaN               3  38.569796
# 173362               NaN       4.0           NaN              36  38.630687
# 173363               NaN       5.0           NaN              78  38.667339
#
#         Longitude  Supplemented  SupplementDate  VictimNum  FirearmUsed  \
# 0      -90.204995           NaN             NaN        NaN          NaN
# 1      -90.264226           NaN             NaN        NaN          NaN
# 2      -90.264226           NaN             NaN        NaN          NaN
# 3      -90.310722           NaN             NaN        NaN          NaN
# 4      -90.243210           NaN             NaN        NaN          NaN
# ...           ...           ...             ...        ...          ...
# 173359 -90.252870           NaN             NaN        NaN          NaN
# 173360 -90.217160           NaN             NaN        NaN          NaN
# 173361 -90.254490           NaN             NaN        NaN          NaN
# 173362 -90.201630           NaN             NaN        NaN          NaN
# 173363 -90.281849           NaN             NaN        NaN          NaN
#
#         IncidentNature
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 173359             NaN
# 173360             NaN
# 173361             NaN
# 173362             NaN
# 173363             NaN
#
# [173364 rows x 21 columns]
